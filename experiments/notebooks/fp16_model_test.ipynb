# %%
from whisper_medium_fp16_transformers import Model, load_audio, pad_or_trim
from IPython.display import Audio
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
# Out:
# 2023-07-12 01:36:06.221323: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model = Model(
            model_name_or_path='whisper_medium_fp16_transformers',
            # cuda_visible_device="1", 
            device='cuda',
      )
# Out:
# Moving model to cuda
# dtype of model acc to config:  torch.float16
# dtype of loaded model:  torch.float16

# %%
audio = load_audio(file='../../audios/song_hi.wav', start_time=0)
audio = pad_or_trim(audio)
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio
# Out:
# array([-0.03732 , -0.0319  , -0.03253 , ..., -0.02307 , -0.0854  ,
#         0.005127], dtype=float16)

# %%
model.transcribe(audio, language="english", skip_special_tokens=False)
# Out:
# '<|startoftranscript|><|en|><|transcribe|> Why does it have to happen? You are the one who makes the day happen The dusk comes in the evening You are the one, you are the one Every moment breathes Life is called<|endoftext|>'
