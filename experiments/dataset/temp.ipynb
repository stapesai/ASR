# %%
from youtube_transcript_api import YouTubeTranscriptApi
from pytube import YouTube
import subprocess

VIDEO_URL = "https://www.youtube.com/watch?v=okvZUE5j4R8"

# %%
def get_subtitle(url):
    srt = YouTubeTranscriptApi.get_transcript(url.split("v=")[1])
    return srt

subtitle = get_subtitle(VIDEO_URL)
subtitle[:]
# Out:
# [{'text': '♡It can be awkward because my English is not perfect♡\nThank you for click this video!!',
#   'start': 12.32,
#   'duration': 4.98},
#  {'text': "Oh, it's cold", 'start': 17.96, 'duration': 0.76},
#  {'text': 'Before drying my hair, comb my bangs',
#   'start': 36.8,
#   'duration': 3.08},
#  {'text': "I'm going to divide the part of the hair neatly",
#   'start': 41.28,
#   'duration': 2.82},
#  {'text': "What's the point of a serious look..lol",
#   'start': 52.02,
#   'duration': 3.22},
#  {'text': 'First, dry my bangs', 'start': 64.58, 'duration': 2.22},
#  {'text': 'and than dry my inner hair', 'start': 66.88, 'duration': 2.74},
#  {'text': 'dry the rest of my hair fast', 'start': 69.78, 'duration': 5.62},
#  {'text': "willl be drying to hair while I'm ready, so I've been drying it for two or three minutes.",
#   'start': 82.72,
#   'duration': 4.52},
#  {'text': '..TTTT', 'start': 88.0, 'duration': 1.46},
#  {'text': 'Always brush the back hair with a brush.',
#   'start': 89.58,
#   'duration': 3.98},
#  {'text': 'The head of the front is the tailbit!',
#   'start': 97.8,
#   'duration': 2.42},
#  {'text': "I'm sleepy.", 'start': 107.58, 'duration': 1.46},
#  {'text': "today's breakfast", 'start': 126.36, 'duration': 1.2},
#  {'text': 'I always eat breakfast!', 'start': 127.6, 'duration': 2.58},
#  {'text': "I'm so hungry if I don't eat.", 'start': 130.18, 'duration': 2.24},
#  {'text': "Because I'm so hungry that I can feel my stomach ache",
#   'start': 133.42,
#   'duration': 1.96},
#  {'text': 'I always eat full', 'start': 135.46, 'duration': 2.3},
#  {'text': 'BlandTTT', 'start': 141.84, 'duration': 1.08},
#  {'text': 'It was bear soup, but it was so bland',
#   'start': 152.0,
#   'duration': 1.64},
#  {'text': 'in the end  I added sal', 'start': 153.78, 'duration': 2.98},
#  {'text': "(even though I'm already eating) I'm hungry",
#   'start': 162.14,
#   'duration': 1.28},
#  {'text': "Noticing that I've too relaxed", 'start': 168.46, 'duration': 3.16},
#  {'text': "Soon it will be 8 o'clock!! (School is until 8:20)",
#   'start': 174.36,
#   'duration': 1.42},
#  {'text': 'Turn on the straightener(Curling iron?)',
#   'start': 175.84,
#   'duration': 0.5},
#  {'text': 'super easy makeup start><', 'start': 176.34, 'duration': 1.6},
#  {'text': 'nterpretation : Vasserin', 'start': 179.5, 'duration': 1.08},
#  {'text': 'The toner is so annoying. Just lotion! hahaha',
#   'start': 183.52,
#   'duration': 2.54},
#  {'text': 'There is no time', 'start': 186.14, 'duration': 0.9},
#  {'text': 'no time', 'start': 188.3, 'duration': 0.76},
#  {'text': "It's been a while since I haven't used my toner",
#   'start': 193.88,
#   'duration': 2.14},
#  {'text': "It's too much hassle", 'start': 196.46, 'duration': 1.12},
#  {'text': 'I have to pack up some water', 'start': 199.36, 'duration': 1.64},
#  {'text': 'Surprise', 'start': 202.54, 'duration': 0.68},
#  {'text': 'I apply my love/suncream\n(TonyMoly- UV master kids gentle sunscreen)',
#   'start': 203.58,
#   'duration': 2.52},
#  {'text': 'If I put the BB or foundation all over my face,',
#   'start': 206.32,
#   'duration': 3.06},
#  {'text': "it's too harmful for your skin", 'start': 209.5, 'duration': 1.54},
#  {'text': "that's why I use sunscreen instead",
#   'start': 211.16,
#   'duration': 2.0},
#  {'text': "My skin won't get damaged because it's for children.",
#   'start': 214.02,
#   'duration': 2.9},
#  {'text': 'putting on multiple layers (does it makes my skin whiter',
#   'start': 228.72,
#   'duration': 2.22},
#  {'text': "And I don't want the difference between the neck and the color",
#   'start': 234.52,
#   'duration': 3.14},
#  {'text': '(checking time)', 'start': 237.66, 'duration': 0.84},
#  {'text': "there's no time", 'start': 238.5, 'duration': 2.14},
#  {'text': 'Why did the time go so fast?', 'start': 243.4, 'duration': 0.84},
#  {'text': 'Usually, she goes out after her makeup in three minutes.LOL',
#   'start': 244.36,
#   'duration': 3.58},
#  {'text': 'I wish I had a whitening sunscreen that I could spray on my neck',
#   'start': 247.94,
#   'duration': 3.02},
#  {'text': 'too annoying', 'start': 251.14, 'duration': 1.0},
#  {'text': 'Now, I applyied suncreen like this,',
#   'start': 252.38,
#   'duration': 1.54},
#  {'text': 'Some parts of the skin are dark and some parts are bright.',
#   'start': 254.0,
#   'duration': 2.96},
#  {'text': 'the coverage of the sunscreen is not enough',
#   'start': 257.04,
#   'duration': 3.08},
#  {'text': 'because sunscreen only increases the tone',
#   'start': 260.12,
#   'duration': 2.26},
#  {'text': "I'm only going to apply the cushion to the dark",
#   'start': 262.38,
#   'duration': 2.48},
#  {'text': '2D4:) Tone Chak Cushion 02 Natural',
#   'start': 265.0,
#   'duration': 1.6},
#  {'text': 'the corners of mouth and nose are darker',
#   'start': 267.1,
#   'duration': 2.68},
#  {'text': 'and a little on the forehead', 'start': 270.08, 'duration': 1.42},
#  {'text': 'Just apply a cushion on this side',
#   'start': 271.82,
#   'duration': 1.7},
#  {'text': 'Just double-cleaning when I cleaning (oil+form cleansing)',
#   'start': 273.58,
#   'duration': 1.56},
#  {'text': 'Powder', 'start': 276.12, 'duration': 0.62},
#  {'text': 'When I am busy, I apply it on while waiting for the elevator. lol',
#   'start': 276.9,
#   'duration': 2.56},
#  {'text': 'Skin Food:) peach bossong multipowder',
#   'start': 279.46,
#   'duration': 1.84},
#  {'text': "I tried to apply it with a brush, but I don't have the time",
#   'start': 281.5,
#   'duration': 3.4},
#  {'text': "It's because I was so relaxed.", 'start': 286.68, 'duration': 1.4},
#  {'text': 'apply it to the center of the T-zone',
#   'start': 288.42,
#   'duration': 2.54},
#  {'text': "I'm going use these two eyebrows",
#   'start': 290.96,
#   'duration': 2.46},
#  {'text': "It's a one day tato brow", 'start': 295.04, 'duration': 2.48},
#  {'text': 'like marker', 'start': 297.52, 'duration': 1.52},
#  {'text': 'A thick brush pen?', 'start': 299.04, 'duration': 1.16},
#  {'text': "If you draw it with this, it'll be erased later",
#   'start': 300.22,
#   'duration': 2.14},
#  {'text': 'so I can use this', 'start': 302.36, 'duration': 1.14},
#  {'text': 'to improve lasting power', 'start': 303.54, 'duration': 1.98},
#  {'text': 'Just paint it where the eyebrows are empty and trim up it up with a screwbrush!',
#   'start': 307.4,
#   'duration': 4.26},
#  {'text': 'If I do this,', 'start': 314.18, 'duration': 0.58},
#  {'text': 'makes me look as natural as my original eyebrows',
#   'start': 314.8,
#   'duration': 2.54},
#  {'text': "Then, it's the beginning", 'start': 317.36, 'duration': 1.86},
#  {'text': "Because it won't be removed unless you wash your face",
#   'start': 319.28,
#   'duration': 2.76},
#  {'text': 'In addition', 'start': 322.16, 'duration': 0.72},
#  {'text': 'this...', 'start': 323.62, 'duration': 0.92},
#  {'text': 'inisfree Flat Eyebrow Pencil No.5 Deep Night Esofra(?)',
#   'start': 324.54,
#   'duration': 2.7},
#  {'text': 'Esaupress Brown!', 'start': 327.24, 'duration': 1.94},
#  {'text': 'Fill in the blanks with this', 'start': 329.24, 'duration': 2.62},
#  {'text': 'And then use a screw brush', 'start': 335.08, 'duration': 3.18},
#  {'text': 'real no time', 'start': 341.5, 'duration': 2.56},
#  {'text': "I usually put on the tint in the elevator, but I'll put it on now because it looks sick",
#   'start': 345.02,
#   'duration': 3.96},
#  {'text': 'Keep in Touch:)\u3000Mood MLBB Velvet-Tint something chili',
#   'start': 349.02,
#   'duration': 2.94},
#  {'text': "I'll just do a ammamma", 'start': 355.08, 'duration': 1.24},
#  {'text': 'This one was on the makeup of the apple princess',
#   'start': 356.32,
#   'duration': 2.9},
#  {'text': "but I only put it on these days because I'm using it so well",
#   'start': 359.22,
#   'duration': 3.04},
#  {'text': 'Something chili Color', 'start': 362.26, 'duration': 0.98},
#  {'text': "I'm going to go straightener", 'start': 367.02, 'duration': 1.86},
#  {'text': 'A lot of people are asking me how to do my hairstyle',
#   'start': 369.18,
#   'duration': 6.08},
#  {'text': "It's really easy!!", 'start': 375.26, 'duration': 1.96},
#  {'text': "I'm not a good person to take care of my hair",
#   'start': 377.22,
#   'duration': 3.22},
#  {'text': 'The bang is', 'start': 381.32, 'duration': 2.04},
#  {'text': 'Just Roll Up', 'start': 383.36, 'duration': 0.92},
#  {'text': "Roll up until it's between your eyebrows and your eyes",
#   'start': 384.38,
#   'duration': 2.14},
#  {'text': 'And my side of the head', 'start': 387.0, 'duration': 1.4},
#  {'text': 'And I put the volume random', 'start': 389.48, 'duration': 1.5},
#  {'text': '(Wow.. so.. useful..(?))', 'start': 390.98, 'duration': 1.18},
#  {'text': 'Twist and give a wave', 'start': 394.72, 'duration': 2.16},
#  {'text': "Just add the volume so it's not boring!!",
#   'start': 397.14,
#   'duration': 4.16},
#  {'text': 'Failed Failed Failed Failed', 'start': 412.14, 'duration': 1.14},
#  {'text': 'Failed Failed Failed', 'start': 413.86, 'duration': 1.0},
#  {'text': 'OH, my hair....', 'start': 414.86, 'duration': 0.76},
#  {'text': 'I made it too radical lol', 'start': 415.62, 'duration': 1.56},
#  {'text': "It's okay", 'start': 417.18, 'duration': 0.62},
#  {'text': 'Because,', 'start': 417.8, 'duration': 0.68},
#  {'text': "It's a vacation ceremony, so I only have three classes",
#   'start': 418.48,
#   'duration': 3.5},
#  {'text': 'If I had slept late today,', 'start': 422.16, 'duration': 2.02},
#  {'text': 'I would not be able to take a picture of GRWM before the winter vacation',
#   'start': 424.24,
#   'duration': 3.82},
#  {'text': "I'm going to do a scarf with a pretty label",
#   'start': 433.78,
#   'duration': 2.0},
#  {'text': 'Dad) Hurry up and $%(?) come', 'start': 440.38, 'duration': 0.88},
#  {'text': 'okay', 'start': 441.26, 'duration': 0.58},
#  {'text': 'what time is it?', 'start': 441.84, 'duration': 1.22},
#  {'text': "If I have time, I'd rather walk (to school)",
#   'start': 443.06,
#   'duration': 1.54},
#  {'text': "I'm going to wear a 'go sister' scarf and a fleece",
#   'start': 455.76,
#   'duration': 4.4},
#  {'text': "Then it's over!", 'start': 460.94, 'duration': 0.86},
#  {'text': 'Is it cold today?', 'start': 462.22, 'duration': 0.94},
#  {'text': "Dad)It's minus 12 degrees", 'start': 463.36, 'duration': 2.0},
#  {'text': "Padded jacket is in my brother's room",
#   'start': 467.74,
#   'duration': 1.3},
#  {'text': 'What floor?', 'start': 469.04, 'duration': 1.0},
#  {'text': 'the first floor below zero(?)', 'start': 470.04, 'duration': 0.82},
#  {'text': "No, it's not the first floor below zero...",
#   'start': 470.86,
#   'duration': 1.78},
#  {'text': "It's winter so I didn't want to catch a cold, so I brought water to Tumblr!",
#   'start': 474.38,
#   'duration': 4.38},
#  {'text': 'Be careful not to catch a cold, too!',
#   'start': 478.76,
#   'duration': 2.0},
#  {'text': 'Is it the first floor? The first basement level?',
#   'start': 486.94,
#   'duration': 1.54},
#  {'text': "It's ready~~", 'start': 498.3, 'duration': 1.16},
#  {'text': "I'll go Bye Bye", 'start': 502.0, 'duration': 1.74},
#  {'text': '(Red Velvet) Shoes advertised by Irene.',
#   'start': 504.92,
#   'duration': 2.3},
#  {'text': 'Dad) Who advertised these shoes?',
#   'start': 507.22,
#   'duration': 1.42},
#  {'text': 'Shoes advertised by Irene', 'start': 508.64, 'duration': 1.8},
#  {'text': 'Today is the vacation ceremony!',
#   'start': 511.16,
#   'duration': 1.38},
#  {'text': 'Actually, I was supposed to walk today,',
#   'start': 517.68,
#   'duration': 3.14},
#  {'text': 'but I was so relaxed', 'start': 520.82, 'duration': 1.96},
#  {'text': "I get up early and relax, so I'm late, if I get up late, I get up late, so I'm late",
#   'start': 522.84,
#   'duration': 2.9},
#  {'text': "It'is fact...", 'start': 525.74, 'duration': 0.76},
#  {'text': 'Actually,', 'start': 529.28, 'duration': 1.26},
#  {'text': 'I can run,', 'start': 530.86, 'duration': 3.52},
#  {'text': "but it's too hard to run on this cold day",
#   'start': 534.54,
#   'duration': 3.06},
#  {'text': 'Dad)12 degrees below zero, freezing to death',
#   'start': 537.6,
#   'duration': 1.72},
#  {'text': 'If it were snowing today, I would be snowman',
#   'start': 539.36,
#   'duration': 3.02},
#  {'text': "This fleece I'm wearing is too soft.",
#   'start': 543.9,
#   'duration': 4.58},
#  {'text': "Now I'm going to put up my winter fashion haul",
#   'start': 548.5,
#   'duration': 2.54},
#  {'text': 'This fleece will go up in the winter fashion haul',
#   'start': 552.68,
#   'duration': 2.14},
#  {'text': 'Going outside', 'start': 559.92, 'duration': 2.2},
#  {'text': "Oh, it's bright.", 'start': 562.68, 'duration': 1.24},
#  {'text': "It's snowing,", 'start': 566.02, 'duration': 0.86},
#  {'text': "and if you'd walked,", 'start': 567.72, 'duration': 1.62},
#  {'text': "you'd be looks like a Park Dae Ki reporter.",
#   'start': 569.34,
#   'duration': 1.26},
#  {'text': '(Park Dae Ki reporter : a reporter who was get snowed on during the heavy snow.)',
#   'start': 570.66,
#   'duration': 3.28},
#  {'text': 'I wore a cute scarf today.', 'start': 573.94, 'duration': 3.04},
#  {'text': "I haven't done much,", 'start': 576.98, 'duration': 1.78},
#  {'text': 'lol', 'start': 578.76, 'duration': 0.5},
#  {'text': 'If you enjoyed it,', 'start': 579.26, 'duration': 1.64},
#  {'text': "I'd appreciate it if you could press like button and subscription",
#   'start': 580.9,
#   'duration': 2.3},
#  {'text': 'and set notification settings', 'start': 583.2, 'duration': 2.84},
#  {'text': "Then we'll meet in the next video",
#   'start': 589.36,
#   'duration': 1.8},
#  {'text': 'bye~~', 'start': 591.74, 'duration': 1.44},
#  {'text': 'It was really sloppy,', 'start': 593.28, 'duration': 1.98},
#  {'text': 'and my video maybe the most sloppy school GRWM(not vlog!)',
#   'start': 595.26,
#   'duration': 5.42},
#  {'text': 'Bye for now!', 'start': 602.98, 'duration': 0.9}]

# %%
def get_best_audio_stream(url):
    # Get YouTube video
    yt = YouTube(url)
    
    # Filter out audio streams with codec 'mp4a.40.5', 'mp4a.40.2', and 'opus'
    audio_streams = yt.streams.filter(only_audio=True)
    
    # Create dictionaries to store information about each codec type
    mp4a_40_5_streams = {}
    mp4a_40_2_streams = {}
    opus_streams = {}
    
    # Group streams by codec type and store the highest quality stream for each
    for stream in audio_streams:
        codecs = stream.parse_codecs()
        if 'mp4a.40.5' in codecs:
            mp4a_40_5_streams[stream.abr] = stream
        elif 'mp4a.40.2' in codecs:
            mp4a_40_2_streams[stream.abr] = stream
        elif 'opus' in codecs:
            opus_streams[stream.abr] = stream
    
    # Choose the highest quality stream among each codec type
    best_mp4a_40_5 = mp4a_40_5_streams[max(mp4a_40_5_streams)]
    best_mp4a_40_2 = mp4a_40_2_streams[max(mp4a_40_2_streams)]
    best_opus = opus_streams[max(opus_streams)]
    
    # Compare the highest quality streams among all codec types
    best_stream = max([best_mp4a_40_5, best_mp4a_40_2, best_opus], key=lambda x: int(x.abr[:-4]))
    
    return best_stream

best_audio_stream = get_best_audio_stream(VIDEO_URL)
best_audio_stream.download(filename="audio.mp4")
# Out:
# '/mnt/nvme/JARVIS/ASR/experiments/dataset/audio.mp4'

# %%
import os
def convert_to_wav(input_file, output_file, sample_rate='16000'):
    os.remove(output_file) if os.path.exists(output_file) else None
    # Use ffmpeg to convert the audio to WAV with specified sample rate
    command = ['ffmpeg', '-i', input_file, '-ar', sample_rate, '-ac', '1', output_file]
    subprocess.run(command)
    os.remove(input_file)

convert_to_wav("audio.mp4", "audio.wav")
# Out:
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'audio.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2019-01-28T07:33:42.000000Z
#   Duration: 00:10:16.51, start: 0.000000, bitrate: 129 kb/s
#     Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 2 kb/s (default)
#     Metadata:
#       creation_time   : 2019-01-28T07:33:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/27/2019.
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'audio.wav':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     ISFT            : Lavf58.29.100
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       creation_time   : 2019-01-28T07:33:42.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 01/27/2019.
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   19266kB time=00:10:16.51 bitrate= 256.0kbits/s speed=1.1e+03x
# video:0kB audio:19266kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000395%

# %%
import whisper
model = whisper.load_model('tiny')

# %%
audio = whisper.load_audio('audio.wav')
audio = whisper.pad_or_trim(audio)
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# %%
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")
# Out:
# Detected language: nn
