# %%
# !pip3 install youtube_transcript_api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Collecting requests (from youtube_transcript_api)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->youtube_transcript_api)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->youtube_transcript_api)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->youtube_transcript_api)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->youtube_transcript_api)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 3.0 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 11.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 10.0 MB/s eta 0:00:00
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.4 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, youtube_transcript_api
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.6 requests-2.31.0 urllib3-2.2.1 youtube_transcript_api-0.6.2

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import re

# Get video ID and download transcripts
video_id = "KrLj6nc516A"
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# Split into sentences and estimate duration per sentence
average_duration_per_sentence = 15  # Adjust based on video content
segmented_subtitles = []

current_start = None
for line in transcript:
    cleaned_text = re.sub(r'\s+', ' ', line["text"]).strip()  # Replace multiple whitespaces with a single space
    text_parts = cleaned_text.split(". ")

    for part in text_parts:
        if current_start is None:
            current_start = line["start"]

        duration = len(part) * average_duration_per_sentence

        # Calculate the ending time stamp
        current_end = current_start + duration

        segmented_subtitles.append({
            "text": part,
            "start": current_start,
            "end": current_end
        })

        current_start = current_end

# Print each sentence along with starting and ending timestamps
for subtitle in segmented_subtitles:
    print(f"Text: {subtitle['text']}")
    print(f"Start Time: {subtitle['start']}, End Time: {subtitle['end']}\n")

# If you want to print the entire segmented_subtitles list, you can use the following:
# print(segmented_subtitles)
# Out:
# Text: Behind me are the most expensive cars in the world.
# Start Time: 0.033, End Time: 765.033
#
# Text: No joke.
# Start Time: 765.033, End Time: 885.033
#
# Text: We got our hands on over $250 million worth of cars,
# Start Time: 885.033, End Time: 1665.033
#
# Text: one of them even costing $100 million.
# Start Time: 1665.033, End Time: 2235.033
#
# Text: And we're going to be exploding sailing, driving
# Start Time: 2235.033, End Time: 2955.033
#
# Text: and even flying all of these cars to show you why they're so expensive.
# Start Time: 2955.033, End Time: 4020.033
#
# Text: Starting with this $1 car, literally a rust bucket.
# Start Time: 4020.033, End Time: 4785.032999999999
#
# Text: Why are you selling this car for a dollar?
# Start Time: 4785.032999999999, End Time: 5415.032999999999
#
# Text: Well, you see, it's pretty much worthless.
# Start Time: 5415.032999999999, End Time: 6045.032999999999
#
# Text: And I can't put any time or money in this thing.
# Start Time: 6045.032999999999, End Time: 6765.032999999999
#
# Text: If you grab this dollar, the deal is final.
# Start Time: 6765.032999999999, End Time: 7410.032999999999
#
# Text: Now, obviously, this is a piece of garbage,
# Start Time: 7410.032999999999, End Time: 8055.032999999999
#
# Text: but when you spend 20 K on repairs, it actually runs.
# Start Time: 8055.032999999999, End Time: 8850.033
#
# Text: All right, let's get this bad boy started.
# Start Time: 8850.033, End Time: 9480.033
#
# Text: I do not think it would start
# Start Time: 9480.033, End Time: 9915.033
#
# Text: How is this thing driving?
# Start Time: 9915.033, End Time: 10305.033
#
# Text: It smells like smoke!
# Start Time: 10305.033, End Time: 10620.033
#
# Text: this is crazy.
# Start Time: 10620.033, End Time: 10830.033
#
# Text: One dollar car!
# Start Time: 10830.033, End Time: 11055.033
#
# Text: One dollar car!
# Start Time: 11055.033, End Time: 11280.033
#
# Text: - One dollar car! - One dollar car!
# Start Time: 11280.033, End Time: 11805.033
#
# Text: One dollar car!
# Start Time: 11805.033, End Time: 12030.033
#
# Text: All right, well, that was the $1 car.
# Start Time: 12030.033, End Time: 12585.033
#
# Text: Glad I wasn't in that.
# Start Time: 12585.033, End Time: 12915.033
#
# Text: Bringing the $100,000 car, which drives itself.
# Start Time: 12915.033, End Time: 13620.033
#
# Text: No joke.
# Start Time: 13620.033, End Time: 13740.033
#
# Text: No one is currently in this car, and it is moving.
# Start Time: 13740.033, End Time: 14490.033
#
# Text: Let's see what 100 grand gets you.
# Start Time: 14490.033, End Time: 15000.033
#
# Text: There's a lot of room in this car.
# Start Time: 15000.033, End Time: 15510.033
#
# Text: This is one of the few cars that can actually fit all my kids.
# Start Time: 15510.033, End Time: 16440.033
#
# Text: - Do you have kids? - Yeah, all of them.
# Start Time: 16440.033, End Time: 17040.033
#
# Text: Let's take it for a little spin.
# Start Time: 17040.033, End Time: 17520.033
#
# Text: The real reason you're buying a Tesla is because it can drive itself.
# Start Time: 17520.033, End Time: 18555.033
#
# Text: All right.
# Start Time: 18555.033, End Time: 18705.033
#
# Text: I'm no longer driving the car.
# Start Time: 18705.033, End Time: 19155.033
#
# Text: Oh, it's switching lanes.
# Start Time: 19155.033, End Time: 19530.033
#
# Text: Oh, it is literally driving itself.
# Start Time: 19530.033, End Time: 20055.033
#
# Text: I'm not touching the gas and I'm not touching the steering wheel.
# Start Time: 20055.033, End Time: 21030.033
#
# Text: Jimmy, are you telling me now you can take a nap while driving?
# Start Time: 21030.033, End Time: 21975.033
#
# Text: - No, don't do that
# Start Time: 21975.033, End Time: 22260.033
#
# Text: - Oh ok.
# Start Time: 22260.033, End Time: 22380.033
#
# Text: Now, let's see how fast the car goes.
# Start Time: 22380.033, End Time: 22935.033
#
# Text: It jerks you backwards.
# Start Time: 22935.033, End Time: 23280.033
#
# Text: That's terrifying.
# Start Time: 23280.033, End Time: 23550.033
#
# Text: This is just the beginning.
# Start Time: 23550.033, End Time: 23955.033
#
# Text: Later, we have a car that literally transforms
# Start Time: 23955.033, End Time: 24645.033
#
# Text: into an airplane and flops.
# Start Time: 24645.033, End Time: 25050.033
#
# Text: But now.
# Start Time: 25050.033, End Time: 25170.033
#
# Text: Oh look that lambo.
# Start Time: 25170.033, End Time: 25455.033
#
# Text: Oh, I almost hit it.
# Start Time: 25455.033, End Time: 25755.033
#
# Text: Bro just left the keys in here
# Start Time: 25755.033, End Time: 26205.033
#
# Text: How'd nobody steal it?
# Start Time: 26205.033, End Time: 26535.033
#
# Text: Even though this cost twice as much, and has half as much space.
# Start Time: 26535.033, End Time: 27495.033
#
# Text: I don't know if I take 200k for this car because I don't fit in it.
# Start Time: 27495.033, End Time: 28500.033
#
# Text: Did they even know how to drive a Lamborghini?
# Start Time: 28500.033, End Time: 29190.033
#
# Text: - How would you do fourth? - I think you just click the shifter.
# Start Time: 29190.033, End Time: 30150.033
#
# Text: All right.
# Start Time: 30150.033, End Time: 30300.033
#
# Text: And now we're on the road.
# Start Time: 30300.033, End Time: 30690.033
#
# Text: Oh, that sound.
# Start Time: 30690.033, End Time: 30915.033
#
# Text: Oh my gosh
# Start Time: 30915.033, End Time: 31065.033
#
# Text: She's out there.
# Start Time: 31065.033, End Time: 31305.033
#
# Text: Hey, she's got some power.
# Start Time: 31305.033, End Time: 31695.033
#
# Text: Oh, my gosh.
# Start Time: 31695.033, End Time: 31875.033
#
# Text: This car is insane.
# Start Time: 31875.033, End Time: 32160.033
#
# Text: I'm barely touching the gas, and we're flying.
# Start Time: 32160.033, End Time: 32850.032999999996
#
# Text: This might be the fastest car I've ever driven.
# Start Time: 32850.032999999996, End Time: 33555.032999999996
#
# Text: If you need to compensate for something,
# Start Time: 33555.032999999996, End Time: 34155.032999999996
#
# Text: this is definitely the car.
# Start Time: 34155.032999999996, End Time: 34560.032999999996
#
# Text: And now we're at the $300,000 car,
# Start Time: 34560.032999999996, End Time: 35070.032999999996
#
# Text: and this is supposedly the safest car on the planet.
# Start Time: 35070.032999999996, End Time: 35850.032999999996
#
# Text: It's like a tank.
# Start Time: 35850.032999999996, End Time: 36105.032999999996
#
# Text: Is this a military-grade car?
# Start Time: 36105.032999999996, End Time: 36540.032999999996
#
# Text: Yeah
# Start Time: 36540.032999999996, End Time: 36600.032999999996
#
# Text: This is so high up.
# Start Time: 36600.032999999996, End Time: 36885.032999999996
#
# Text: You were also just in the Lamborghini.
# Start Time: 36885.032999999996, End Time: 37455.032999999996
#
# Text: True, true perspective.
# Start Time: 37455.032999999996, End Time: 37800.032999999996
#
# Text: Let's go over what makes this car so safe.
# Start Time: 37800.032999999996, End Time: 38430.032999999996
#
# Text: First things first is the bulletproof windows that are this thick.
# Start Time: 38430.032999999996, End Time: 39420.032999999996
#
# Text: The car is also encased in explosive proof armor
# Start Time: 39420.032999999996, End Time: 40140.032999999996
#
# Text: that we're going to put to the test later on.
# Start Time: 40140.032999999996, End Time: 40815.032999999996
#
# Text: - Karl, do you want to press the button? - So bad.
# Start Time: 40815.032999999996, End Time: 41565.032999999996
#
# Text: - You want to hit the smokescreen button? - Please?
# Start Time: 41565.032999999996, End Time: 42330.032999999996
#
# Text: That is crazy.
# Start Time: 42330.032999999996, End Time: 42540.032999999996
#
# Text: We have a literal smokescreen.
# Start Time: 42540.032999999996, End Time: 42990.032999999996
#
# Text: Oh, my gosh, It smells.
# Start Time: 42990.032999999996, End Time: 43335.032999999996
#
# Text: But the best part is none of these features are
# Start Time: 43335.032999999996, End Time: 44040.032999999996
#
# Text: what makes the car really safe.
# Start Time: 44040.032999999996, End Time: 44505.032999999996
#
# Text: It's the little explosive proof frame around the car.
# Start Time: 44505.032999999996, End Time: 45300.032999999996
#
# Text: And we're going to be the first people to test it.
# Start Time: 45300.032999999996, End Time: 46050.032999999996
#
# Text: And for reference, before we blow up the $300,000 car,
# Start Time: 46050.032999999996, End Time: 46860.032999999996
#
# Text: we're going to blow up on normal cars to see if the passengers survive.
# Start Time: 46860.032999999996, End Time: 47925.032999999996
#
# Text: Three, two, one.
# Start Time: 47925.032999999996, End Time: 48165.032999999996
#
# Text: Not only is it on fire, but the mannequins
# Start Time: 48165.032999999996, End Time: 48795.032999999996
#
# Text: literally flew out of the car.
# Start Time: 48795.032999999996, End Time: 49245.032999999996
#
# Text: We blew a sunroof into that thing.
# Start Time: 49245.032999999996, End Time: 49755.032999999996
#
# Text: It doesn't handle it well at all.
# Start Time: 49755.032999999996, End Time: 50250.032999999996
#
# Text: And before we blow up this car, I'm going to put feastables inside
# Start Time: 50250.032999999996, End Time: 51240.032999999996
#
# Text: Better protect my freaking chocolate.
# Start Time: 51240.032999999996, End Time: 51795.032999999996
#
# Text: So supposedly this car is explosion proof, but that's never been tested.
# Start Time: 51795.032999999996, End Time: 52875.032999999996
#
# Text: Let's see if the mannequins
# Start Time: 52875.032999999996, End Time: 53280.032999999996
#
# Text: and even more importantly, the Feastables survive.
# Start Time: 53280.032999999996, End Time: 54030.032999999996
#
# Text: Three, two, one.
# Start Time: 54030.032999999996, End Time: 54270.032999999996
#
# Text: It just jumped.
# Start Time: 54270.032999999996, End Time: 54495.032999999996
#
# Text: The car survived the blast with only a few minor scrapes.
# Start Time: 54495.032999999996, End Time: 55350.032999999996
#
# Text: It put a dent in the window
# Start Time: 55350.032999999996, End Time: 55755.032999999996
#
# Text: Wait
# Start Time: 55755.032999999996, End Time: 55815.032999999996
#
# Text: Hold on, hold on.
# Start Time: 55815.032999999996, End Time: 56070.032999999996
#
# Text: Where are the feastables? Chandler, get out the way.
# Start Time: 56070.032999999996, End Time: 56850.032999999996
#
# Text: The feastables survive.
# Start Time: 56850.032999999996, End Time: 57195.032999999996
#
# Text: If you're looking for a car that can take a bomb,
# Start Time: 57195.032999999996, End Time: 57930.032999999996
#
# Text: I officially recommend this one.
# Start Time: 57930.032999999996, End Time: 58410.032999999996
#
# Text: But since you're not going to war anytime soon for only an extra
# Start Time: 58410.032999999996, End Time: 59370.032999999996
#
# Text: $200,000, you could get this $500,000 boat car.
# Start Time: 59370.032999999996, End Time: 60075.032999999996
#
# Text: On land this is a normal car.
# Start Time: 60075.032999999996, End Time: 60510.032999999996
#
# Text: You can't really tell the difference
# Start Time: 60510.032999999996, End Time: 61050.032999999996
#
# Text: But here's the fun part.
# Start Time: 61050.032999999996, End Time: 61410.032999999996
#
# Text: Just drive it in the water and it turns into a boat.
# Start Time: 61410.032999999996, End Time: 62190.032999999996
#
# Text: We'll let Karl go first.
# Start Time: 62190.032999999996, End Time: 62550.032999999996
#
# Text: - Here we go
# Start Time: 62550.032999999996, End Time: 62730.032999999996
#
# Text: - Oh, this doesn't feel right.
# Start Time: 62730.032999999996, End Time: 63180.032999999996
#
# Text: This doesn't feel right.
# Start Time: 63180.032999999996, End Time: 63540.032999999996
#
# Text: I'm having them go first just so I can make sure it works.
# Start Time: 63540.032999999996, End Time: 64410.032999999996
#
# Text: Are we sinking, no we are floating!
# Start Time: 64410.032999999996, End Time: 64935.032999999996
#
# Text: Oh, it looks like it worked
# Start Time: 64935.032999999996, End Time: 65340.032999999996
#
# Text: Let's see what happens.
# Start Time: 65340.032999999996, End Time: 65685.033
#
# Text: Oh, my God
# Start Time: 65685.033, End Time: 65835.033
#
# Text: We're driving in the water.
# Start Time: 65835.033, End Time: 66240.033
#
# Text: Oh, so you press this until you hear a beep.
# Start Time: 66240.033, End Time: 66900.033
#
# Text: That's a beep.
# Start Time: 66900.033, End Time: 67110.033
#
# Text: Now, I should be able to drive this like a normal car, but on the water.
# Start Time: 67110.033, End Time: 68190.033
#
# Text: Thea hold on.
# Start Time: 68190.033, End Time: 68385.033
#
# Text: This is incredible.
# Start Time: 68385.033, End Time: 68670.033
#
# Text: This was literally a car five seconds ago.
# Start Time: 68670.033, End Time: 69300.033
#
# Text: Yeah!
# Start Time: 69300.033, End Time: 69375.033
#
# Text: I would be out there with them, but I get carsick and boat sick.
# Start Time: 69375.033, End Time: 70335.033
#
# Text: Oh, hey there.
# Start Time: 70335.033, End Time: 70545.033
#
# Text: Oh my God.
# Start Time: 70545.033, End Time: 70695.033
#
# Text: All right, Karl!
# Start Time: 70695.033, End Time: 70935.033
#
# Text: Karl!
# Start Time: 70935.033, End Time: 71010.033
#
# Text: They should not let me drive this
# Start Time: 71010.033, End Time: 71505.033
#
# Text: We got it baby.
# Start Time: 71505.033, End Time: 71730.033
#
# Text: Rule number one, stay really far away from Kris.
# Start Time: 71730.033, End Time: 72450.033
#
# Text: We're driving in circles.
# Start Time: 72450.033, End Time: 72825.033
#
# Text: Oh, they're doing donuts in the water, they're making a whirlpool.
# Start Time: 72825.033, End Time: 73815.033
#
# Text: I just met this guy 5 seconds ago.
# Start Time: 73815.033, End Time: 74325.033
#
# Text: We're going to race
# Start Time: 74325.033, End Time: 74610.033
#
# Text: three, two, one
# Start Time: 74610.033, End Time: 74835.033
#
# Text: Go!
# Start Time: 74835.033, End Time: 74880.033
#
# Text: He is so much faster.
# Start Time: 74880.033, End Time: 75195.033
#
# Text: He's not even trying
# Start Time: 75195.033, End Time: 75495.033
#
# Text: Come on
# Start Time: 75495.033, End Time: 75600.033
#
# Text: Faster.
# Start Time: 75600.033, End Time: 75705.033
#
# Text: Oh, we're destroying him.
# Start Time: 75705.033, End Time: 76080.033
#
# Text: - He's slowing down
# Start Time: 76080.033, End Time: 76365.033
#
# Text: - I can't believe we just beat him.
# Start Time: 76365.033, End Time: 76890.033
#
# Text: This thing goes way too fast.
# Start Time: 76890.033, End Time: 77325.033
#
# Text: I can't think of a better way to celebrate a win than a Feastables Bar.
# Start Time: 77325.033, End Time: 78390.033
#
# Text: Hey, have some feastables.
# Start Time: 78390.033, End Time: 78780.033
#
# Text: I got it.
# Start Time: 78780.033, End Time: 78915.033
#
# Text: Feastables the number one chocolate on the planet.
# Start Time: 78915.033, End Time: 79665.033
#
# Text: If you're not eating it, you should fix that.
# Start Time: 79665.033, End Time: 80340.033
#
# Text: The fact that all three of us are driving cars on the ocean is insane.
# Start Time: 80340.033, End Time: 81390.033
#
# Text: Jimmy, I love this thing so much.
# Start Time: 81390.033, End Time: 81885.033
#
# Text: The craziest part is this is just the beginning of this video.
# Start Time: 81885.033, End Time: 82815.033
#
# Text: The next car on our list can literally fly.
# Start Time: 82815.033, End Time: 83460.033
#
# Text: And since I'm afraid of heights, I'll let Karl and Nolan take this one.
# Start Time: 83460.033, End Time: 84525.033
#
# Text: Dude, what is happening?
# Start Time: 84525.033, End Time: 84885.033
#
# Text: This car is not only completely street legal, but it also has wings
# Start Time: 84885.033, End Time: 85890.033
#
# Text: that can take it to literally
# Start Time: 85890.033, End Time: 86325.033
#
# Text: 8000 feet in the sky.
# Start Time: 86325.033, End Time: 86640.033
#
# Text: There's literally a propeller on that car.
# Start Time: 86640.033, End Time: 87270.033
#
# Text: Stay here and watch it take off.
# Start Time: 87270.033, End Time: 87750.033
#
# Text: I'm going to go in that plane and follow it.
# Start Time: 87750.033, End Time: 88410.033
#
# Text: I just don't believe this is actually going to fly
# Start Time: 88410.033, End Time: 89160.033
#
# Text: It's taking off!
# Start Time: 89160.033, End Time: 89400.033
#
# Text: The wheels aren't on the ground anymore.
# Start Time: 89400.033, End Time: 90000.033
#
# Text: It's literally a car that's flying.
# Start Time: 90000.033, End Time: 90525.033
#
# Text: These cars are getting crazier and crazier.
# Start Time: 90525.033, End Time: 91170.033
#
# Text: I can't even believe my eyes.
# Start Time: 91170.033, End Time: 91605.033
#
# Text: There is a car a mile above my head right now.
# Start Time: 91605.033, End Time: 92295.033
#
# Text: Oh, this so cool.
# Start Time: 92295.033, End Time: 92550.033
#
# Text: I feel like for $600,000, this is a steal.
# Start Time: 92550.033, End Time: 93180.033
#
# Text: Prepare for landing.
# Start Time: 93180.033, End Time: 93480.033
#
# Text: Up next is the $1 million car.
# Start Time: 93480.033, End Time: 93930.033
#
# Text: But I didn't only bring one up.
# Start Time: 93930.033, End Time: 94395.033
#
# Text: As you can imagine, there's a lot of $1 million cars out there.
# Start Time: 94395.033, End Time: 95340.033
#
# Text: So to make sure I brought your favorite,
# Start Time: 95340.033, End Time: 95940.033
#
# Text: we got the ten coolest $1 million cars.
# Start Time: 95940.033, End Time: 96525.033
#
# Text: And as per usual, we have the entire racetrack to ourselves.
# Start Time: 96525.033, End Time: 97425.033
#
# Text: So I let my friends choose whatever car they want.
# Start Time: 97425.033, End Time: 98175.033
#
# Text: I'm going to ride with you
# Start Time: 98175.033, End Time: 98565.033
#
# Text: You pick.
# Start Time: 98565.033, End Time: 98700.033
#
# Text: Look at this baby.
# Start Time: 98700.033, End Time: 98970.033
#
# Text: Am I going to fit in this?
# Start Time: 98970.033, End Time: 99360.033
#
# Text: All right
# Start Time: 99360.033, End Time: 99495.033
#
# Text: I'll try not to text and drive.
# Start Time: 99495.033, End Time: 99960.033
#
# Text: It's private property
# Start Time: 99960.033, End Time: 100275.033
#
# Text: It's technically legal here.
# Start Time: 100275.033, End Time: 100695.033
#
# Text: Oh, here we go.
# Start Time: 100695.033, End Time: 100920.033
#
# Text: We're never going to die.
# Start Time: 100920.033, End Time: 101295.033
#
# Text: Don't jinx it.
# Start Time: 101295.033, End Time: 101505.033
#
# Text: I feel like I'm in NASCAR.
# Start Time: 101505.033, End Time: 101895.033
#
# Text: I'm having so much fun
# Start Time: 101895.033, End Time: 102225.033
#
# Text: This feels like Fast & Furious.
# Start Time: 102225.033, End Time: 102690.033
#
# Text: There's just something so masculine about driving over priced loud cars.
# Start Time: 102690.033, End Time: 103770.033
#
# Text: On a private racetrack.
# Start Time: 103770.033, End Time: 104115.033
#
# Text: On a private racetrack.
# Start Time: 104115.033, End Time: 104460.033
#
# Text: Hold on
# Start Time: 104460.033, End Time: 104565.033
#
# Text: I got to send a text.
# Start Time: 104565.033, End Time: 104880.033
#
# Text: No, I'm kidding.
# Start Time: 104880.033, End Time: 105120.033
#
# Text: - I'm crashing this
# Start Time: 105120.033, End Time: 105405.033
#
# Text: - Please no.
# Start Time: 105405.033, End Time: 105585.033
#
# Text: Karl!
# Start Time: 105585.033, End Time: 105660.033
#
# Text: Oh, my God.
# Start Time: 105660.033, End Time: 105825.033
#
# Text: We're doing donuts in a million dollar car.
# Start Time: 105825.033, End Time: 106470.033
#
# Text: While the gang is whizzing around the track,
# Start Time: 106470.033, End Time: 107130.033
#
# Text: I want to show you the next car.
# Start Time: 107130.033, End Time: 107610.033
#
# Text: This $2 million limited edition hydrogen car.
# Start Time: 107610.033, End Time: 108285.033
#
# Text: No joke.
# Start Time: 108285.033, End Time: 108405.033
#
# Text: This car is completely powered by hydrogen and actually exhales
# Start Time: 108405.033, End Time: 109350.033
#
# Text: drinkable water as exhaust, but the car still being developed.
# Start Time: 109350.033, End Time: 110280.033
#
# Text: So this is just a prototype.
# Start Time: 110280.033, End Time: 110700.033
#
# Text: I don't think I've ever struggled this much to get in a car.
# Start Time: 110700.033, End Time: 111600.033
#
# Text: All right
# Start Time: 111600.033, End Time: 111735.033
#
# Text: Let's see how she closes.
# Start Time: 111735.033, End Time: 112110.033
#
# Text: First impressions, door kind of slow.
# Start Time: 112110.033, End Time: 112665.033
#
# Text: We're about to turn on the road.
# Start Time: 112665.033, End Time: 113145.033
#
# Text: This is a really big deal because
# Start Time: 113145.033, End Time: 113640.033
#
# Text: this car has never been driven on a road before.
# Start Time: 113640.033, End Time: 114360.033
#
# Text: Oh, you should have told me before I got here.
# Start Time: 114360.033, End Time: 115050.033
#
# Text: They built this car as a proof of concept.
# Start Time: 115050.033, End Time: 115680.033
#
# Text: So driving on the road is questionable.
# Start Time: 115680.033, End Time: 116265.033
#
# Text: Well, look at that lady over there.
# Start Time: 116265.033, End Time: 116790.033
#
# Text: That person over there is literally filming our car.
# Start Time: 116790.033, End Time: 117570.033
#
# Text: And while we're driving, I want to tell you
# Start Time: 117570.033, End Time: 118215.033
#
# Text: about the Samsung Galaxy Z Flip 5 phone.
# Start Time: 118215.033, End Time: 118815.033
#
# Text: And what's special about this phone is it literally folds in half.
# Start Time: 118815.033, End Time: 119805.033
#
# Text: Boom, half the size.
# Start Time: 119805.033, End Time: 120105.033
#
# Text: Also, I'd wear a seat belt, but it doesn't have
# Start Time: 120105.033, End Time: 120810.033
#
# Text: they haven't gone that far yet.
# Start Time: 120810.033, End Time: 121275.033
#
# Text: Folding screen on the flip five makes the phone
# Start Time: 121275.033, End Time: 121980.033
#
# Text: fit in your pocket better
# Start Time: 121980.033, End Time: 122355.033
#
# Text: and also allows you to use two apps at the same time.
# Start Time: 122355.033, End Time: 123150.033
#
# Text: - Show them
# Start Time: 123150.033, End Time: 123315.033
#
# Text: - Let me show you.
# Start Time: 123315.033, End Time: 123585.033
#
# Text: On the bottom half of the phone,
# Start Time: 123585.033, End Time: 124065.033
#
# Text: I have Google and on the top half
# Start Time: 124065.033, End Time: 124560.033
#
# Text: We're watching a MrBeast video.
# Start Time: 124560.033, End Time: 125025.033
#
# Text: Oh, snap.
# Start Time: 125025.033, End Time: 125160.033
#
# Text: - Bro, this boy gets up there
# Start Time: 125160.033, End Time: 125595.033
#
# Text: - Yeah.
# Start Time: 125595.033, End Time: 125700.033
#
# Text: Even though this car uses hydrogen instead of gas, it still has a range
# Start Time: 125700.033, End Time: 126765.033
#
# Text: of over a thousand miles, top speed of 221 miles per hour.
# Start Time: 126765.033, End Time: 127635.033
#
# Text: And another cool thing about this phone is it can record in 4K 60 fps.
# Start Time: 127635.033, End Time: 128685.033
#
# Text: You can even record while it's folded.
# Start Time: 128685.033, End Time: 129255.033
#
# Text: In fact
# Start Time: 129255.033, End Time: 129360.033
#
# Text: The Samsung Galaxy s23 Ultra is the official vlog camera of the channel.
# Start Time: 129360.033, End Time: 130440.033
#
# Text: Listen to that engine.
# Start Time: 130440.033, End Time: 130770.033
#
# Text: - What? - That's such a cool sound.
# Start Time: 130770.033, End Time: 131295.033
#
# Text: It literally has a front facing camera even when you close it down.
# Start Time: 131295.033, End Time: 132300.033
#
# Text: The Flip5 is the most innovative phone Samsung has ever made.
# Start Time: 132300.033, End Time: 133215.033
#
# Text: Click the link in the description to get one right now.
# Start Time: 133215.033, End Time: 134040.033
#
# Text: Do it.
# Start Time: 134040.033, End Time: 134130.033
#
# Text: There's a lot of cars around me and everywhere.
# Start Time: 134130.033, End Time: 134835.033
#
# Text: Get away from my $2 million car.
# Start Time: 134835.033, End Time: 135315.033
#
# Text: I'll see you at the next car.
# Start Time: 135315.033, End Time: 135750.033
#
# Text: Back at the racetrack, we have the most exotic and powerful car yet.
# Start Time: 135750.033, End Time: 136770.033
#
# Text: Costing $10 million.
# Start Time: 136770.033, End Time: 137070.033
#
# Text: This Koenigsegg Vader is the only one in existence.
# Start Time: 137070.033, End Time: 137835.033
#
# Text: So this is the world's fastest production car.
# Start Time: 137835.033, End Time: 138525.033
#
# Text: Oh, my gosh.
# Start Time: 138525.033, End Time: 138705.033
#
# Text: And with literal crushed diamonds in the paint,
# Start Time: 138705.033, End Time: 139410.033
#
# Text: the insurance companies only let the owner drive.
# Start Time: 139410.033, End Time: 140145.033
#
# Text: That's probably the coolest door I've ever seen in my life.
# Start Time: 140145.033, End Time: 141030.033
#
# Text: You're crazy.
# Start Time: 141030.033, End Time: 141225.033
#
# Text: - All right, let's do this
# Start Time: 141225.033, End Time: 141615.033
#
# Text: - Let's do it.
# Start Time: 141615.033, End Time: 141825.033
#
# Text: Fun fact, I made a grown man cry.
# Start Time: 141825.033, End Time: 142320.033
#
# Text: - Really? - Yeah
# Start Time: 142320.033, End Time: 142560.033
#
# Text: I scared the crap out of him.
# Start Time: 142560.033, End Time: 142995.033
#
# Text: I'm going to put my head back so I don't get whiplash.
# Start Time: 142995.033, End Time: 143805.033
#
# Text: How was it so fast?
# Start Time: 143805.033, End Time: 144090.033
#
# Text: I've never...
# Start Time: 144090.033, End Time: 144285.033
#
# Text: Watch out for that.
# Start Time: 144285.033, End Time: 144570.033
#
# Text: The reason this car is one of the fastest
# Start Time: 144570.033, End Time: 145185.033
#
# Text: on the planet is because of its twin turbocharged V8 engine
# Start Time: 145185.033, End Time: 146070.033
#
# Text: and the fact that its entire frame is made out of air core carbon fiber,
# Start Time: 146070.033, End Time: 147150.033
#
# Text: making it weigh almost 500 pounds less than a Lamborghini.
# Start Time: 147150.033, End Time: 148020.033
#
# Text: I've never witnessed anything like this before.
# Start Time: 148020.033, End Time: 148725.033
#
# Text: It's like riding in a roller coaster.
# Start Time: 148725.033, End Time: 149280.033
#
# Text: My heart is pounding.
# Start Time: 149280.033, End Time: 149595.033
#
# Text: Well, that was awesome
# Start Time: 149595.033, End Time: 149925.033
#
# Text: Thank you, sir.
# Start Time: 149925.033, End Time: 150150.033
#
# Text: Thank you.
# Start Time: 150150.033, End Time: 150300.033
#
# Text: Let's go hang out with Jay Leno
# Start Time: 150300.033, End Time: 150765.033
#
# Text: and see what a $20 million car looks like.
# Start Time: 150765.033, End Time: 151395.033
#
# Text: All right.
# Start Time: 151395.033, End Time: 151545.033
#
# Text: Jay Leno was the king of The Tonight Show for over 20 years.
# Start Time: 151545.033, End Time: 152445.033
#
# Text: Today, he's the proud owner of one of the most impressive
# Start Time: 152445.033, End Time: 153300.033
#
# Text: car collections in the world, including this $20 million McLaren F1.
# Start Time: 153300.033, End Time: 154320.033
#
# Text: Did it just start doing that because of you?
# Start Time: 154320.033, End Time: 154980.033
#
# Text: It's high tech.
# Start Time: 154980.033, End Time: 155205.033
#
# Text: Robbers don't try that.
# Start Time: 155205.033, End Time: 155550.033
#
# Text: And what makes it so valuable?
# Start Time: 155550.033, End Time: 156000.033
#
# Text: It's a V12 carbon fiber.
# Start Time: 156000.033, End Time: 156360.033
#
# Text: It's extremely light.
# Start Time: 156360.033, End Time: 156675.033
#
# Text: And it was 241 miles an hour,
# Start Time: 156675.033, End Time: 157110.033
#
# Text: which is still the fastest for a non turbocharged non supercharged car.
# Start Time: 157110.033, End Time: 158175.033
#
# Text: I'll show you something kind of cool.
# Start Time: 158175.033, End Time: 158730.033
#
# Text: It got three seats, as you can see.
# Start Time: 158730.033, End Time: 159255.033
#
# Text: The car is about 2300 pounds.
# Start Time: 159255.033, End Time: 159690.033
#
# Text: Your most modern cars are 4,000.
# Start Time: 159690.033, End Time: 160170.033
#
# Text: It's more comparable to Nolan's mom than another car.
# Start Time: 160170.033, End Time: 160965.033
#
# Text: That's right
# Start Time: 160965.033, End Time: 161145.033
#
# Text: Exactly.
# Start Time: 161145.033, End Time: 161265.033
#
# Text: In fact, Nolan's mom was really the one they used as the benchmark.
# Start Time: 161265.033, End Time: 162270.033
#
# Text: - You guys want to go for a ride? - Of course.
# Start Time: 162270.033, End Time: 162960.033
#
# Text: There's no way to get in that middle seat
# Start Time: 162960.033, End Time: 163575.033
#
# Text: It's actually uncomfortable.
# Start Time: 163575.033, End Time: 163995.033
#
# Text: Oh, it's not bad.
# Start Time: 163995.033, End Time: 164250.033
#
# Text: Yeah, it's not bad
# Start Time: 164250.033, End Time: 164520.033
#
# Text: Did not look bad at all
# Start Time: 164520.033, End Time: 164865.033
#
# Text: It's comfortable.
# Start Time: 164865.033, End Time: 165120.033
#
# Text: It's oddly comfortable to have three seats like this.
# Start Time: 165120.033, End Time: 165915.033
#
# Text: Yeah, it is pretty interesting,
# Start Time: 165915.033, End Time: 166380.033
#
# Text: Normally this is where the wheel would be.
# Start Time: 166380.033, End Time: 167010.033
#
# Text: Or if you were in England.
# Start Time: 167010.033, End Time: 167400.033
#
# Text: this is where the steering wheel would be.
# Start Time: 167400.033, End Time: 168030.033
#
# Text: You can be in England, you can be in America.
# Start Time: 168030.033, End Time: 168705.033
#
# Text: How long have you had this car?
# Start Time: 168705.033, End Time: 169170.033
#
# Text: - What year were you born? - 1998.
# Start Time: 169170.033, End Time: 169680.033
#
# Text: Actually, I got this in 98.
# Start Time: 169680.033, End Time: 170085.033
#
# Text: I popped out of my mom and he's like, "let's celebrate by buying this car."
# Start Time: 170085.033, End Time: 171210.033
#
# Text: Here's the second part.
# Start Time: 171210.033, End Time: 171555.033
#
# Text: I'm your dad.
# Start Time: 171555.033, End Time: 171750.033
#
# Text: Interesting.
# Start Time: 171750.033, End Time: 171930.033
#
# Text: How much did you buy this for?
# Start Time: 171930.033, End Time: 172380.033
#
# Text: I paid 800,000, and I bought it.
# Start Time: 172380.033, End Time: 172860.033
#
# Text: And people thought you'll never get your money back.
# Start Time: 172860.033, End Time: 173640.033
#
# Text: But then it just went up and up and up and up.
# Start Time: 173640.033, End Time: 174330.033
#
# Text: And now there's $20 million, you know?
# Start Time: 174330.033, End Time: 174900.033
#
# Text: So it's crazy.
# Start Time: 174900.033, End Time: 175110.033
#
# Text: This car basically made you a millon dollars a year every year.
# Start Time: 175110.033, End Time: 176055.033
#
# Text: I guess that's fair to say.
# Start Time: 176055.033, End Time: 176460.033
#
# Text: Karl, what do you think of the car?
# Start Time: 176460.033, End Time: 176985.033
#
# Text: I like it.
# Start Time: 176985.033, End Time: 177135.033
#
# Text: What's stopping you from buying one
# Start Time: 177135.033, End Time: 177660.033
#
# Text: $19.9 million?
# Start Time: 177660.033, End Time: 177870.033
#
# Text: Have you ever had a wreck?
# Start Time: 177870.033, End Time: 178260.033
#
# Text: Oh, yeah.
# Start Time: 178260.033, End Time: 178395.033
#
# Text: I've had a lot of wrecks.
# Start Time: 178395.033, End Time: 178770.033
#
# Text: Thank you so much for taking us out.
# Start Time: 178770.033, End Time: 179310.033
#
# Text: No problem, guys.
# Start Time: 179310.033, End Time: 179565.033
#
# Text: That was perfect.
# Start Time: 179565.033, End Time: 179820.033
#
# Text: These next two cars are so expensive, They're locked away in a museum
# Start Time: 179820.033, End Time: 180855.033
#
# Text: at all times.
# Start Time: 180855.033, End Time: 181050.033
#
# Text: Combined, they cost $80 million.
# Start Time: 181050.033, End Time: 181530.033
#
# Text: And somehow we convinced the museum to give us the cars.
# Start Time: 181530.033, End Time: 182370.033
#
# Text: Looking good.
# Start Time: 182370.033, End Time: 182565.033
#
# Text: And this is where the video gets literally mind blowing.
# Start Time: 182565.033, End Time: 183405.033
#
# Text: Crank this bad boy up.
# Start Time: 183405.033, End Time: 183735.033
#
# Text: That's 30 miller.
# Start Time: 183735.033, End Time: 183990.033
#
# Text: Let's hear that 50 miller.
# Start Time: 183990.033, End Time: 184380.033
#
# Text: Not going to lie
# Start Time: 184380.033, End Time: 184620.033
#
# Text: I like the $50 miller one a little better.
# Start Time: 184620.033, End Time: 185250.033
#
# Text: So I jumped in the $50 million car with Donut Media and Chandler
# Start Time: 185250.033, End Time: 186210.033
#
# Text: got in the $30 million car with Beau Boeckmann, the car legend.
# Start Time: 186210.033, End Time: 187155.033
#
# Text: You ready?
# Start Time: 187155.033, End Time: 187305.033
#
# Text: - Are you ready? - I'm ready.
# Start Time: 187305.033, End Time: 187740.033
#
# Text: Let's do this.
# Start Time: 187740.033, End Time: 187950.033
#
# Text: The reason the car that Chandler's in is so expensive
# Start Time: 187950.033, End Time: 188745.033
#
# Text: is because it was constructed specifically as a gift
# Start Time: 188745.033, End Time: 189525.033
#
# Text: from the founder of Ferrari to the founder of Ford.
# Start Time: 189525.033, End Time: 190290.033
#
# Text: This is the only version of this Ferrari ever made in human history.
# Start Time: 190290.033, End Time: 191310.033
#
# Text: Watch out for this bump.
# Start Time: 191310.033, End Time: 191670.033
#
# Text: No scraping.
# Start Time: 191670.033, End Time: 191850.033
#
# Text: You don't really notice how, like, crappy
# Start Time: 191850.033, End Time: 192465.033
#
# Text: the street is until you drive something that's $50 million.
# Start Time: 192465.033, End Time: 193350.033
#
# Text: The car we're in is the most expensive Jaguar in existence.
# Start Time: 193350.033, End Time: 194235.033
#
# Text: It was the legendary actor Steve McQueen's daily driver,
# Start Time: 194235.033, End Time: 195075.033
#
# Text: and he got so many speeding tickets driving it,
# Start Time: 195075.033, End Time: 195780.033
#
# Text: his license was actually suspended.
# Start Time: 195780.033, End Time: 196305.033
#
# Text: I'm noticing every single pothole now.
# Start Time: 196305.033, End Time: 196875.033
#
# Text: And because these cars are so expensive,
# Start Time: 196875.033, End Time: 197475.033
#
# Text: we have an entire police escort dedicated to making
# Start Time: 197475.033, End Time: 198240.033
#
# Text: sure nobody comes close to the cars.
# Start Time: 198240.033, End Time: 198780.033
#
# Text: This is insane.
# Start Time: 198780.033, End Time: 199005.033
#
# Text: Hey, get some speed.
# Start Time: 199005.033, End Time: 199305.033
#
# Text: - How's it drive? - Beautifully.
# Start Time: 199305.033, End Time: 199785.033
#
# Text: Oh my hat!
# Start Time: 199785.033, End Time: 199935.033
#
# Text: Oh well.
# Start Time: 199935.033, End Time: 200055.033
#
# Text: While we were all having fun, Beau Boeckmann pushed
# Start Time: 200055.033, End Time: 200820.033
#
# Text: this $30 million car to its absolute limit.
# Start Time: 200820.033, End Time: 201465.033
#
# Text: Wait, wait, wait
# Start Time: 201465.033, End Time: 201705.033
#
# Text: Hold on.
# Start Time: 201705.033, End Time: 201825.033
#
# Text: Hold on
# Start Time: 201825.033, End Time: 201930.033
#
# Text: The car is stuck.
# Start Time: 201930.033, End Time: 202185.033
#
# Text: Hold on one second.
# Start Time: 202185.033, End Time: 202470.033
#
# Text: We hit it too..
# Start Time: 202470.033, End Time: 202695.033
#
# Text: too hard.
# Start Time: 202695.033, End Time: 202830.033
#
# Text: The $30 million car stalled.
# Start Time: 202830.033, End Time: 203250.033
#
# Text: We're going to hop out of these things before we break them.
# Start Time: 203250.033, End Time: 204150.033
#
# Text: Let's go drive the $100 million world's first Ferrari.
# Start Time: 204150.033, End Time: 204960.033
#
# Text: Most people would imagine $100 million car
# Start Time: 204960.033, End Time: 205590.033
#
# Text: would look something more like this.
# Start Time: 205590.033, End Time: 206130.033
#
# Text: But you'd be surprised to find out that this is the $100 million car.
# Start Time: 206130.033, End Time: 207165.033
#
# Text: This car is so historic and valuable that this museum representative
# Start Time: 207165.033, End Time: 208185.033
#
# Text: is literally the only person on earth allowed to drive it.
# Start Time: 208185.033, End Time: 209055.033
#
# Text: It's only allowed to be driven on this bridge.
# Start Time: 209055.033, End Time: 209745.033
#
# Text: We had cops completely closed the roads.
# Start Time: 209745.033, End Time: 210345.033
#
# Text: We even had street cleaners fill in every pothole
# Start Time: 210345.033, End Time: 211080.033
#
# Text: and clean the entire street to ensure
# Start Time: 211080.033, End Time: 211635.033
#
# Text: that there's no chance that we harm this hundred million dollar car.
# Start Time: 211635.033, End Time: 212655.033
#
# Text: This is going to be crazy.
# Start Time: 212655.033, End Time: 213045.033
#
# Text: All right
# Start Time: 213045.033, End Time: 213180.033
#
# Text: And now we're on the bridge.
# Start Time: 213180.033, End Time: 213600.033
#
# Text: Oh, my God.
# Start Time: 213600.033, End Time: 213765.033
#
# Text: Look at that.
# Start Time: 213765.033, End Time: 213960.033
#
# Text: $100 million barreling down the street.
# Start Time: 213960.033, End Time: 214545.033
#
# Text: Oh, I keep losing my hat.
# Start Time: 214545.033, End Time: 214920.033
#
# Text: He lost his hat.
# Start Time: 214920.033, End Time: 215160.033
#
# Text: That's the second time.
# Start Time: 215160.033, End Time: 215505.033
#
# Text: Most expensive car comes with a free hat.
# Start Time: 215505.033, End Time: 216120.033
#
# Text: Come on.
# Start Time: 216120.033, End Time: 216240.033
#
# Text: Come on!
# Start Time: 216240.033, End Time: 216360.033
#
# Text: This is awesome.
# Start Time: 216360.033, End Time: 216600.033
#
# Text: Name one thing more fun than this.
# Start Time: 216600.033, End Time: 217110.033
#
# Text: All right.
# Start Time: 217110.033, End Time: 217260.033
#
# Text: Floor it.
# Start Time: 217260.033, End Time: 217395.033
#
# Text: Let's go.
# Start Time: 217395.033, End Time: 217530.033
#
# Text: Oh, my God
# Start Time: 217530.033, End Time: 217680.033
#
# Text: It's awesome.
# Start Time: 217680.033, End Time: 217875.033
#
# Text: I hope you guys enjoyed the video
# Start Time: 217875.033, End Time: 218370.033
#
# Text: Let's drop a nuke on the bridge.
# Start Time: 218370.033, End Time: 218850.033
#
# Text: Subscribe to get Nolan’s mom a treadmill
# Start Time: 218850.033, End Time: 219450.033
#
# Text: Just kidding we love you nolan’s mom
# Start Time: 219450.033, End Time: 219990.033
